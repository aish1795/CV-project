# %%
import matplotlib.pyplot as plt

# %%
epochs = [e for e in range(1, 21)]

t_sup = [2.0125789642333984, 1.897297739982605, 1.8589304685592651, 1.827455759048462, 1.8033955097198486, 1.7789145708084106, 1.7506626844406128, 1.7325056791305542, 1.7020978927612305, 1.6716424226760864, 1.645663857460022, 1.619307279586792, 1.5814965963363647, 1.550676703453064, 1.508174180984497, 1.4752087593078613, 1.436067819595337, 1.3878638744354248, 1.3541415929794312, 1.3040093183517456]
t_base = [1.9599, 1.8797, 1.8423, 1.8158, 1.755, 1.7136, 1.6534, 1.577, 1.4923, 1.4067, 1.1331, 1.0331, 0.9696, 0.9176, 0.862, 0.8019, 0.7696, 0.7621, 0.7459, 0.7373]
t_un = [1.9916, 1.9416, 1.9141, 1.9004, 1.8783, 1.8571, 1.8262, 1.7989, 1.7657, 1.7148, 1.6627, 1.6171, 1.564, 1.5096, 1.4459, 1.3996, 1.3403, 1.2862, 1.2337, 1.1871]
t_self = [2.2126, 2.0247, 2.0132, 2.0248, 1.9983, 1.9989, 2.0027, 2.001, 1.8286, 1.7243, 1.6946, 1.5687, 1.3772, 1.2631, 1.0847, 1.0248, 0.8533, 0.7748, 0.7722, 0.7705]
t_res = [2.0216, 1.9754, 1.9606, 1.9744, 1.9351, 1.9218, 1.903, 1.8894, 1.882, 1.8755, 1.8565, 1.8416, 1.8231, 1.8121, 1.7482, 1.6939, 1.6699, 1.6299, 1.592, 1.5514]

plt.plot(epochs, t_sup, label='Vision Transformer pre-trained using supervised learning')
plt.plot(epochs, t_base, label='Baseline model: VGG16')
plt.plot(epochs, t_self, label='Vision Transformer pre-trained using self-supervised learning')
plt.plot(epochs, t_un, label='Vision Transformer without any pre-training')
plt.plot(epochs, t_res, label='ResNet 34')

plt.legend(bbox_to_anchor=(0.5,-0.5), loc="lower center", ncol=1)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.xticks(epochs)
plt.title('Training loss')
plt.show()

v_sup = [1.923085598945617, 1.887705101966858, 1.8511362695693971, 1.863413546085358, 1.840927965641022, 1.8245143389701848, 1.8465001535415642, 1.8236996388435365, 1.8197083282470703, 1.8086443352699275, 1.8463986086845403, 1.8327659416198734, 1.8445799446105957, 1.8292727208137514, 1.8715635609626773, 1.8074671387672425, 1.8614068102836605, 1.8446386373043058, 1.8718260431289675, 1.8406116533279416]
v_base = [1.9345, 1.9707, 1.9246, 1.9467, 1.8942, 1.9328, 1.9123, 1.9411, 1.9757, 1.9769, 2.2158, 2.389, 2.4823, 2.6529, 2.8061, 2.8159, 2.8167, 2.8252, 2.8259, 2.8293]
v_un = [1.9464, 1.8951, 1.8859, 1.8757, 1.8521, 1.8567, 1.8401, 1.8398, 1.8635, 1.8872, 1.9103, 1.9686, 1.9898, 2.0083, 2.1427, 2.1225, 2.2065, 2.3068, 2.3061, 2.3894]
v_self = [2.046, 1.9827, 1.9949, 1.9692, 1.9928, 1.9737, 1.9811, 1.9735, 1.879, 1.8238, 1.7951, 1.7902, 1.7239, 1.6295, 1.6163, 1.6065, 1.5564, 1.4999, 1.5955, 1.5953]
v_res = [2.0074, 1.9997, 1.9881, 1.9136, 2.1175, 1.9548, 1.9095, 1.8721, 1.87, 1.8798, 1.9227, 1.9313, 1.9148, 1.882, 1.8176, 1.8427, 1.87, 1.8733, 1.9118, 1.9453]


plt.plot(epochs, v_sup, label='Vision Transformer pre-trained using supervised learning')
plt.plot(epochs, v_base, label='Baseline model: VGG16')
plt.plot(epochs, v_self, label='Vision Transformer pre-trained using self-supervised learning')
plt.plot(epochs, v_un, label='Vision Transformer without any pre-training')
plt.plot(epochs, v_res, label='ResNet 34')

plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(bbox_to_anchor=(0.5,-0.5), loc="lower center", ncol=1)
plt.xticks(epochs)
plt.title('Validation loss')
plt.show()
